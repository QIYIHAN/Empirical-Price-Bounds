# %%
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
import gurobipy as gp
from gurobipy import GRB

options = {
    "WLSACCESSID": "31598bc4-0b23-474f-86d4-af032d437137",
    "WLSSECRET": "bd7ad348-f8d6-452e-b615-ebc88d920e41",
    "LICENSEID": 2498404,
}

# %%
df = pd.read_csv('data_20180119_20180420.csv', index_col=0)
df.head()
# Out:
#            t0          T1      K1       C1          T2      K2          C2  \
# 0  2018-01-02  2018-01-19  1000.0  191.525  2018-04-20   800.0  396.725000
# 1  2018-01-02  2018-01-19  1100.0   92.525  2018-04-20  1015.0  191.675000
# 2  2018-01-02  2018-01-19  1150.0   46.075  2018-04-20  1025.0  183.025000
# 3  2018-01-02  2018-01-19  1160.0   38.000  2018-04-20  1050.0  157.776341
# 4  2018-01-02  2018-01-19  1170.0   30.450  2018-04-20  1080.0  137.850000
#
#         S0      Adj_S0
# 0  59.4505  1189.01001
# 1  59.4505  1189.01001
# 2  59.4505  1189.01001
# 3  59.4505  1189.01001
# 4  59.4505  1189.01001

# %%
t0List = list(df.t0.unique())

# %%
NList = [5, 10, 15, 20, 25, 30, 35, 40, 50]

# %% [markdown]
# ### Linear Programming Problem
# min $d+\sum_{n=1}^{N_1}\lambda_{n,1}\Pi_{n,1}+\sum_{n=1}^{N_2}\lambda_{n,2}\Pi_{n,2}$
#
# s.t. $d+\sum_{n=1}^{N_1}\lambda_{n,1}(S_1^i-K_{n,1})^++\sum_{n=1}^{N_2}\lambda_{n,2}(S_2^j-K_{n,2})^++\Delta_{0}\cdot(S_1^i-S_0)+\Delta_{1}^i\cdot(S_2^j-S_1^i) \geq \Phi(S_1^i,S_2^j), i,j=1,...,N$

# %%
def payoff(S1,S2):
    return max(S2 - S1, 0)

# %%
stocks = pd.read_csv('adjusted_stocks.csv')
realS1 = stocks.loc[stocks.Date=='2018-01-19', 'AMZN'].item()
realS2 = stocks.loc[stocks.Date=='2018-04-20', 'AMZN'].item()

# %%
def params_N(df, t0List, N):
    parameters = {}
    
    for t0 in t0List:
        df_t0 = df.loc[df.t0 == t0].copy()
        
        C1 = df_t0['C1']
        C2 = df_t0['C2']
        K1 = df_t0['K1']
        K2 = df_t0['K2']
        
        S0 = df_t0['Adj_S0'].unique()
        # Adjustment of I_ref
        I_ref = 50
        d_S1, u_S1 = min(K1)-I_ref, max(K1)+I_ref
        d_S2, u_S2 = min(K2)-I_ref, max(K2)+I_ref
        while realS1 > u_S1:
            u_S1 += I_ref
        while realS1 < d_S1:
            d_S1 -= I_ref
        while realS2 > u_S2:
            u_S2 += I_ref
        while realS2 < d_S2:
            d_S2 -= I_ref
        S1 = np.linspace(d_S1, u_S1, N)
        S2 = np.linspace(d_S2, u_S2, N)
        
        m = gp.Model("Price Bounds")
        d = m.addVars(['d'], name="d")
        lamb1 = m.addVars(df_t0.index, name="lamb1")
        lamb2 = m.addVars(df_t0.index, name="lamb2")
        delta0 = m.addVars(['delta0'], name="delta0")
        delta1 = m.addVars(np.array(S1).flatten(), name="delta1")
        
        m.setObjective(d['d']+sum(lamb1[r]*C1[r]+lamb2[r]*C2[r] for r in df_t0.index))
        m.ModelSense = GRB.MINIMIZE
        
        for S1_i in S1:
            for S2_j in S2:
                m.addConstr(d['d'] + sum(lamb1[r]*max(S1_i-K1[r],0)+lamb2[r]*max(S2_j-K2[r],0) for r in df_t0.index) + 
                            delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
                            >= payoff(S1_i, S2_j), 'C_{}{}'.format(S1_i, S2_j))
                m.update()
        
        m.optimize()
        
        if m.status == GRB.OPTIMAL:
            var = {v.varName: v.x for v in m.getVars()}
            
            delta1_values = np.array([var['delta1[{}]'.format(s1)] for s1 in S1])
            delta1_interpolator = CubicSpline(S1, delta1_values)
            
            parameters[t0] = {
                'd': var['d[d]'],
                'lamb1': {r: var['lamb1[{}]'.format(r)] for r in df_t0.index},
                'lamb2': {r: var['lamb2[{}]'.format(r)] for r in df_t0.index},
                'delta0': var['delta0[delta0]'],
                'delta1': delta1_interpolator
            }
        else:
            print("Optimization was not successful.")
        
    return parameters

# %%
def hedgingStrategy(parameters, S0, K1, K2):
    h = (parameters[t0]['d']
         + sum(parameters[t0]['lamb1'][r] * max(realS1-K1[r],0) + 
               parameters[t0]['lamb2'][r] * max(realS2-K2[r],0) for r in df_t0.index)
         + parameters[t0]['delta0'] * (realS1 - S0)
         + parameters[t0]['delta1'](realS1) * (realS2-realS1)
        )
    return h

# %%
hMatrix = np.zeros((len(NList), len(t0List)))

# %%
for i in range(len(NList)):
    N = NList[i]
    parameters = params_N(df, t0List, N)
    for j in range(len(t0List)):
        t0 = t0List[j]
        df_t0 = df.loc[df.t0 == t0].copy()
        S0 = df_t0['Adj_S0'].unique()
        K1 = df_t0['K1']
        K2 = df_t0['K2']
        h = hedgingStrategy(parameters, S0, K1, K2)
        
        hMatrix[i,j] = h
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 515 nonzeros
# Model fingerprint: 0x7212290e
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [8e-01, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 7e+02]
# Presolve removed 0 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 43 columns, 495 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.507812e+02   0.000000e+00      0s
#       12    1.3587302e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.358730159e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 675 nonzeros
# Model fingerprint: 0x7943ed70
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 6e+02]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 46 columns, 670 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.549609e+02   0.000000e+00      0s
#       10    1.0510987e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.051098660e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 573 nonzeros
# Model fingerprint: 0x19eb5657
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 6e+02]
# Presolve removed 5 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 42 columns, 447 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.195312e+02   0.000000e+00      0s
#        5    9.5308594e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.530859375e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 625 nonzeros
# Model fingerprint: 0x9f78f960
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 5e+02]
# Presolve time: 0.00s
# Presolved: 25 rows, 47 columns, 625 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.467187e+02   0.000000e+00      0s
#       11    9.5678840e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.567884027e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 579 nonzeros
# Model fingerprint: 0xd2abb7f6
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 5e+02]
# Presolve removed 1 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 43 columns, 535 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.281250e+02   0.000000e+00      0s
#       10    1.0473750e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.047375000e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 600 nonzeros
# Model fingerprint: 0xcca86c9f
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 7e+02]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 46 columns, 595 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.215625e+02   0.000000e+00      0s
#        8    9.7884370e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.788437044e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 595 nonzeros
# Model fingerprint: 0xfd971fd8
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 7e+02]
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 45 columns, 585 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.849219e+02   0.000000e+00      0s
#       10    1.0436467e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.043646701e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 569 nonzeros
# Model fingerprint: 0x0072fc0c
# Coefficient statistics:
#   Matrix range     [2e-13, 6e+02]
#   Objective range  [9e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 4e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 45 columns, 520 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.921875e+01   0.000000e+00      0s
#       11    1.1664687e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.166468750e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 610 nonzeros
# Model fingerprint: 0xdcc30db6
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [6e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 4e+02]
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 45 columns, 600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.097656e+02   0.000000e+00      0s
#       10    1.1689175e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.168917526e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 639 nonzeros
# Model fingerprint: 0x62c4bd2b
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 47 columns, 602 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.650000e+02   0.000000e+00      0s
#       10    1.0518695e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.051869550e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 580 nonzeros
# Model fingerprint: 0x74ecadb1
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 4e+02]
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 45 columns, 570 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.427344e+02   0.000000e+00      0s
#        9    1.0181969e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.018196856e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 645 nonzeros
# Model fingerprint: 0x75ad35d7
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [3e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 6e+02]
# Presolve removed 0 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 44 columns, 610 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.625000e+02   0.000000e+00      0s
#        9    1.0037575e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.003757509e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 25 rows, 47 columns and 555 nonzeros
# Model fingerprint: 0x7fbc677c
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [5e-03, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve removed 0 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 25 rows, 42 columns, 515 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.248438e+02   0.000000e+00      0s
#       12    1.0051574e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.005157389e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2078 nonzeros
# Model fingerprint: 0x117e7edf
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [8e-01, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 7e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 99 rows, 52 columns, 2040 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.555556e+02   0.000000e+00      0s
#       31    1.4533853e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.453385309e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2709 nonzeros
# Model fingerprint: 0xcd27bca7
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2709 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.550694e+02   0.000000e+00      0s
#       18    1.0565173e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.056517326e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2277 nonzeros
# Model fingerprint: 0xc064377f
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 6e+02]
# Presolve removed 10 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 90 rows, 51 columns, 2093 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.536458e+02   0.000000e+00      0s
#       24    1.0066768e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.006676829e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2480 nonzeros
# Model fingerprint: 0x5af1be32
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 5e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.012847e+02   0.000000e+00      0s
#       26    9.7406579e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.740657895e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2300 nonzeros
# Model fingerprint: 0x3b346559
# Coefficient statistics:
#   Matrix range     [6e-01, 6e+02]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 5e+02]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 100 rows, 51 columns, 2290 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.715278e+02   0.000000e+00      0s
#       27    1.0897991e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.089799129e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2439 nonzeros
# Model fingerprint: 0xc9eea5ea
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 7e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 99 rows, 52 columns, 2401 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.436111e+02   0.000000e+00      0s
#       24    9.8739497e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.873949683e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2360 nonzeros
# Model fingerprint: 0x61313b9e
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 7e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2360 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.999653e+02   0.000000e+00      0s
#       25    1.0476205e+02   0.000000e+00   0.000000e+00      0s
# Solved in 25 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.047620505e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2309 nonzeros
# Model fingerprint: 0xb4315cfb
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [9e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 4e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2309 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.949653e+02   0.000000e+00      0s
#       22    1.1712838e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.171283840e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2459 nonzeros
# Model fingerprint: 0xb6ceea05
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [6e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 4e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2459 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.010417e+02   0.000000e+00      0s
#       19    1.1864674e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.186467391e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2570 nonzeros
# Model fingerprint: 0x2d2205cf
# Coefficient statistics:
#   Matrix range     [3e-01, 8e+02]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2570 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.134028e+02   0.000000e+00      0s
#       27    1.0521584e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.052158395e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2360 nonzeros
# Model fingerprint: 0x7df08be9
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+00, 4e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2360 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.736285e+02   0.000000e+00      0s
#       25    1.0297693e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.029769303e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2660 nonzeros
# Model fingerprint: 0x2587f198
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [3e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 6e+02]
# Presolve time: 0.00s
# Presolved: 100 rows, 52 columns, 2660 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.998958e+02   0.000000e+00      0s
#       32    1.0048232e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.004823212e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 100 rows, 52 columns and 2199 nonzeros
# Model fingerprint: 0xe7fde195
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [5e-03, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 6e+02]
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 99 rows, 51 columns, 2174 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.767014e+02   0.000000e+00      0s
#       27    1.0207337e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.020733688e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 4648 nonzeros
# Model fingerprint: 0x188b3381
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [8e-01, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 7e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 224 rows, 57 columns, 4615 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.218304e+03   0.000000e+00      0s
#       35    1.4567973e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.456797348e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 6135 nonzeros
# Model fingerprint: 0xf0b71063
# Coefficient statistics:
#   Matrix range     [7e-01, 8e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 225 rows, 57 columns, 6135 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.390491e+03   0.000000e+00      0s
#       37    1.0585474e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 37 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.058547375e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5172 nonzeros
# Model fingerprint: 0x32a653af
# Coefficient statistics:
#   Matrix range     [2e-13, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 15 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 210 rows, 56 columns, 4914 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.670089e+03   0.000000e+00      0s
#       32    1.0087121e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.008712112e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5625 nonzeros
# Model fingerprint: 0x1a0d4f4c
# Coefficient statistics:
#   Matrix range     [2e-13, 5e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 5e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve time: 0.00s
# Presolved: 225 rows, 57 columns, 5625 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.405603e+03   0.000000e+00      0s
#       43    9.7665984e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 43 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.766598412e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5174 nonzeros
# Model fingerprint: 0xc609bc72
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 5e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 224 rows, 57 columns, 5150 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.125357e+03   0.000000e+00      0s
#       39    1.0947710e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.094770997e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5505 nonzeros
# Model fingerprint: 0x1a9d22bc
# Coefficient statistics:
#   Matrix range     [7e-01, 7e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-01, 7e+02]
# Presolve time: 0.00s
# Presolved: 225 rows, 57 columns, 5505 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.714598e+03   0.000000e+00      0s
#       39    9.8998369e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.899836887e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5354 nonzeros
# Model fingerprint: 0xdad1661f
# Coefficient statistics:
#   Matrix range     [7e-01, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 225 rows, 57 columns, 5354 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.853616e+03   0.000000e+00      0s
#       38    1.0490678e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.049067816e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5204 nonzeros
# Model fingerprint: 0x8823c23d
# Coefficient statistics:
#   Matrix range     [4e-01, 6e+02]
#   Objective range  [9e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 224 rows, 57 columns, 5174 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.248884e+02   0.000000e+00      0s
#       29    1.1708439e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.170843861e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5579 nonzeros
# Model fingerprint: 0xb8f21203
# Coefficient statistics:
#   Matrix range     [7e-01, 6e+02]
#   Objective range  [6e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 224 rows, 57 columns, 5544 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.619978e+02   0.000000e+00      0s
#       25    1.1864674e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.186467391e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5819 nonzeros
# Model fingerprint: 0x39610c88
# Coefficient statistics:
#   Matrix range     [7e-01, 8e+02]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 224 rows, 57 columns, 5782 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.519241e+03   0.000000e+00      0s
#       38    1.0527563e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.052756260e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5280 nonzeros
# Model fingerprint: 0x131e2592
# Coefficient statistics:
#   Matrix range     [7e-01, 6e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve time: 0.00s
# Presolved: 225 rows, 57 columns, 5280 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.355792e+03   0.000000e+00      0s
#       36    1.0298193e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.029819327e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 6000 nonzeros
# Model fingerprint: 0x36361561
# Coefficient statistics:
#   Matrix range     [7e-01, 7e+02]
#   Objective range  [3e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 225 rows, 57 columns, 6000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.489397e+03   0.000000e+00      0s
#       38    1.0049458e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.004945771e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 225 rows, 57 columns and 5010 nonzeros
# Model fingerprint: 0x09095168
# Coefficient statistics:
#   Matrix range     [2e-13, 7e+02]
#   Objective range  [5e-03, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 225 rows, 56 columns, 4905 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.802500e+03   0.000000e+00      0s
#       53    1.0215004e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 53 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.021500419e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8298 nonzeros
# Model fingerprint: 0xd8c37e84
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [8e-01, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 7e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 8271 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.138158e+03   0.000000e+00      0s
#       45    1.4581406e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 45 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.458140635e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11000 nonzeros
# Model fingerprint: 0x67821105
# Coefficient statistics:
#   Matrix range     [1e-02, 8e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 11000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.547911e+03   0.000000e+00      0s
#       42    1.0586358e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.058635807e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9216 nonzeros
# Model fingerprint: 0x95268772
# Coefficient statistics:
#   Matrix range     [2e-13, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8894 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.901563e+03   0.000000e+00      0s
#       48    1.0098187e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 48 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.009818708e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9920 nonzeros
# Model fingerprint: 0x20addddb
# Coefficient statistics:
#   Matrix range     [2e-13, 5e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 5e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9920 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.585888e+03   0.000000e+00      0s
#       42    9.7690907e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.769090740e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9260 nonzeros
# Model fingerprint: 0xd7b1851d
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9260 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.953289e+03   0.000000e+00      0s
#       34    1.0958507e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.095850695e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9780 nonzeros
# Model fingerprint: 0xc90fecf6
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9780 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.088191e+03   0.000000e+00      0s
#       53    9.9070170e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 53 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.907017032e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9420 nonzeros
# Model fingerprint: 0x3b0af14f
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9420 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.345559e+03   0.000000e+00      0s
#       49    1.0497744e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.049774432e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9218 nonzeros
# Model fingerprint: 0x28412000
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [9e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 9181 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.491447e+03   0.000000e+00      0s
#       36    1.1712884e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.171288361e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9919 nonzeros
# Model fingerprint: 0xaf6e3d19
# Coefficient statistics:
#   Matrix range     [6e-02, 6e+02]
#   Objective range  [6e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 9881 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.499507e+03   0.000000e+00      0s
#       24    1.1864674e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.186467391e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10360 nonzeros
# Model fingerprint: 0x77d24ea8
# Coefficient statistics:
#   Matrix range     [1e-01, 8e+02]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10360 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.791842e+03   0.000000e+00      0s
#       49    1.0526743e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.052674339e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9379 nonzeros
# Model fingerprint: 0x455e3a0f
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9379 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.210757e+03   0.000000e+00      0s
#       43    1.0297310e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 43 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.029731016e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10699 nonzeros
# Model fingerprint: 0xa8a11163
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+02]
#   Objective range  [3e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 10682 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.735987e+03   0.000000e+00      0s
#       44    1.0050048e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 44 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.005004808e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8880 nonzeros
# Model fingerprint: 0xd9c0a81e
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+02]
#   Objective range  [5e-03, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 8880 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.255197e+03   0.000000e+00      0s
#       59    1.0222589e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 59 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.022258851e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 625 rows, 67 columns and 12797 nonzeros
# Model fingerprint: 0x7394365d
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [8e-01, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 7e+02]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 623 rows, 67 columns, 12736 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.314844e+03   0.000000e+00      0s
#       47    1.4582027e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 47 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.458202660e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 625 rows, 67 columns and 17174 nonzeros
# Model fingerprint: 0xfc4265cd
# Coefficient statistics:
#   Matrix range     [2e-01, 8e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 625 rows, 67 columns, 17174 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.863932e+03   0.000000e+00      0s
#       46    1.0591336e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 46 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.059133610e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 625 rows, 67 columns and 14268 nonzeros
# Model fingerprint: 0x94725b15
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 6e+02]
# Presolve removed 27 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 598 rows, 66 columns, 13796 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.797852e+03   0.000000e+00      0s
#       49    1.0107606e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.010760639e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 625 rows, 67 columns and 15600 nonzeros
# Model fingerprint: 0x12d22007
# Coefficient statistics:
#   Matrix range     [2e-13, 5e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve time: 0.00s
# Presolved: 625 rows, 67 columns, 15600 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.003802e+03   0.000000e+00      0s
#       58    9.7734076e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  9.773407561e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 625 rows, 67 columns and 14474 nonzeros
# Model fingerprint: 0xdfd3ea26
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 5e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 624 rows, 67 columns, 14450 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.139062e+03   0.000000e+00      0s
#       50    1.0963288e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 50 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.096328828e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 625 rows, 67 columns and 15300 nonzeros
# Model fingerprint: 0xf7a20191
# Coefficient statistics:
#   Matrix range     [8e-01, 7e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 625 rows, 67 columns, 15300 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.924049e+03   0.000000e+00      0s
#       64    9.9144788e+01   0.000000e+00   0.000000e+00      0s
#
# ...
# Model fingerprint: 0xc42b4363
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [6e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-01, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1224 rows, 77 columns, 30313 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.720335e+03   0.000000e+00      0s
#       44    1.1865296e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 44 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.186529641e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1225 rows, 77 columns and 31709 nonzeros
# Model fingerprint: 0xa05a1cca
# Coefficient statistics:
#   Matrix range     [6e-01, 8e+02]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-01, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1224 rows, 77 columns, 31672 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.320533e+03   0.000000e+00      0s
#       88    1.0527723e+02   0.000000e+00   0.000000e+00      0s
# Solved in 88 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.052772313e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1225 rows, 77 columns and 28805 nonzeros
# Model fingerprint: 0x9d41b94b
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-01, 4e+02]
# Presolve time: 0.01s
# Presolved: 1225 rows, 77 columns, 28805 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.876163e+03   0.000000e+00      0s
#       72    1.0298226e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 72 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.029822632e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1225 rows, 77 columns and 32830 nonzeros
# Model fingerprint: 0x0f2fb7d6
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+02]
#   Objective range  [3e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 6e+02]
# Presolve time: 0.01s
# Presolved: 1225 rows, 77 columns, 32830 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.150175e+03   0.000000e+00      0s
#       72    1.0050372e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 72 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.005037230e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1225 rows, 77 columns and 27055 nonzeros
# Model fingerprint: 0xb55ae16b
# Coefficient statistics:
#   Matrix range     [6e-01, 7e+02]
#   Objective range  [5e-03, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-01, 6e+02]
# Presolve time: 0.01s
# Presolved: 1225 rows, 77 columns, 27055 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.972086e+03   0.000000e+00      0s
#      104    1.0221786e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 104 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.022178631e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 32996 nonzeros
# Model fingerprint: 0xb5eb8452
# Coefficient statistics:
#   Matrix range     [2e-13, 8e+02]
#   Objective range  [8e-01, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 7e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1598 rows, 82 columns, 32927 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.583253e+03   0.000000e+00      0s
#       84    1.4586706e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 84 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  1.458670642e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 43960 nonzeros
# Model fingerprint: 0xfbb018bf
# Coefficient statistics:
#   Matrix range     [2e-13, 8e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-13, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 43960 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.959856e+03   0.000000e+00      0s
#       72    1.0596481e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 72 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.059648118e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 36831 nonzeros
# Model fingerprint: 0x0110205f
# Coefficient statistics:
#   Matrix range     [2e-13, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-13, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 43 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 1557 rows, 81 columns, 36098 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.263882e+04   0.000000e+00      0s
#       80    1.0112664e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 80 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.011266444e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 40039 nonzeros
# Model fingerprint: 0x08b2a25c
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 5e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 40039 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.041872e+04   0.000000e+00      0s
#       87    9.7743828e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 87 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  9.774382843e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 36960 nonzeros
# Model fingerprint: 0xe7dda35c
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 5e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 36960 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.824038e+03   0.000000e+00      0s
#       76    1.0965390e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 76 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  1.096539005e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 39320 nonzeros
# Model fingerprint: 0xa33d0bd3
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 7e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 39320 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.269415e+04   0.000000e+00      0s
#      100    9.9179312e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 100 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  9.917931227e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 38039 nonzeros
# Model fingerprint: 0x435de3fc
# Coefficient statistics:
#   Matrix range     [3e-01, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 7e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 38039 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.326431e+04   0.000000e+00      0s
#      102    1.0503330e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 102 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.050332955e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 36916 nonzeros
# Model fingerprint: 0x225edd39
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [9e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1598 rows, 82 columns, 36846 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.078045e+03   0.000000e+00      0s
#       64    1.1713032e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 64 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  1.171303243e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 39758 nonzeros
# Model fingerprint: 0x20d7c27b
# Coefficient statistics:
#   Matrix range     [6e-02, 6e+02]
#   Objective range  [6e-01, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-01, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1599 rows, 82 columns, 39723 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.093670e+03   0.000000e+00      0s
#       49    1.1865430e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.186543023e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 41359 nonzeros
# Model fingerprint: 0x18cb94a1
# Coefficient statistics:
#   Matrix range     [3e-01, 8e+02]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 1599 rows, 82 columns, 41335 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.094760e+04   0.000000e+00      0s
#       86    1.0527615e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 86 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.052761497e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 37640 nonzeros
# Model fingerprint: 0xe7b509c2
# Coefficient statistics:
#   Matrix range     [1e-01, 6e+02]
#   Objective range  [5e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 4e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 37640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.045417e+03   0.000000e+00      0s
#       74    1.0298568e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 74 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  1.029856835e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 42880 nonzeros
# Model fingerprint: 0x1b444cd8
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+02]
#   Objective range  [3e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 6e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 42880 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.072481e+04   0.000000e+00      0s
#       82    1.0050434e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 82 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.005043392e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1600 rows, 82 columns and 35360 nonzeros
# Model fingerprint: 0x9f16c95d
# Coefficient statistics:
#   Matrix range     [3e-01, 7e+02]
#   Objective range  [5e-03, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 6e+02]
# Presolve time: 0.01s
# Presolved: 1600 rows, 82 columns, 35360 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.309681e+04   0.000000e+00      0s
#      138    1.0223900e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 138 iterations and 0.01 seconds (0.02 work units)
# Optimal objective  1.022390022e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[27], line 3
#       1 for i in range(len(NList)):
#       2     N = NList[i]
# ----> 3     parameters = params_N(df, t0List, N)
#       4     for j in range(len(t0List)):
#       5         t0 = t0List[j]
#
# Cell In[19], line 44, in params_N(df, t0List, N)
#      39         m.addConstr(d['d'] + sum(lamb1[r]*max(S1_i-K1[r],0)+lamb2[r]*max(S2_j-K2[r],0) for r in df_t0.index) +
#      40                     delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
#      41                     >= payoff(S1_i, S2_j), 'C_{}{}'.format(S1_i, S2_j))
#      42         m.update()
# ---> 44 m.optimize()
#      46 if m.status == GRB.OPTIMAL:
#      47     var = {v.varName: v.x for v in m.getVars()}
#
# File src/gurobipy/model.pxi:893, in gurobipy.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information

# %%
gapMatrix = hMatrix - payoff(realS1, realS2)

# %%
for i in range(len(NList)):
    plt.plot(t0List, gapMatrix[i, :], '-o', label=f'N={NList[i]}')
plt.xticks(rotation=45)
plt.legend()
plt.title('Accuracy with incresing N')
plt.show()
