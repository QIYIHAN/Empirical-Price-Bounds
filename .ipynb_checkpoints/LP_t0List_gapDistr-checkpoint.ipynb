# %%
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
import gurobipy as gp
from gurobipy import GRB

options = {
    "WLSACCESSID": "31598bc4-0b23-474f-86d4-af032d437137",
    "WLSSECRET": "bd7ad348-f8d6-452e-b615-ebc88d920e41",
    "LICENSEID": 2498404,
}

# %%
import os
import re

# %% [markdown]
# tickerList = ['AMZN', 'GOOGL', 'JNJ', 'JPM', 'MSFT', 'PG', 'TSLA', 'V', 'WMT']

# %%
data_path = f'data/paired_Option'
data_files = os.listdir(data_path)
# print(sorted(data_files))

# %%
pattern = r'^([A-Z]+)_(\d{8})_(\d{8})\.csv$'

# %%
N = 20

# %%
def payoff(S1,S2):
    return max(S2 - S1, 0)

# %%
stocks = pd.read_csv('adjusted_stocks.csv')
stocks.head()
# Out:
#          Date         AMZN        JPM         JNJ       MSFT         PG  \
# 0  2018-01-02  1189.010010  90.125488  117.502670  80.080925  76.669670
# 1  2018-01-03  1204.199982  90.217331  118.625122  80.453613  76.576607
# 2  2018-01-04  1209.589996  91.509758  118.616730  81.161705  77.117928
# 3  2018-01-05  1229.140015  90.922310  119.595680  82.167976  77.168678
# 4  2018-01-08  1246.869965  91.056587  119.747589  82.251801  77.574646
#
#          WMT        GOOGL           V        TSLA
# 0  88.322428  1073.209991  109.733635  320.530014
# 1  89.092855  1091.520004  110.826103  317.249994
# 2  89.173491  1095.759964  111.238144  314.619999
# 3  89.702036  1110.289993  113.902199  316.580000
# 4  91.027891  1114.209976  114.362175  336.410007

# %%
def params(df_t0, N):    
    C1 = df_t0['C1']
    C2 = df_t0['C2']
    K1 = df_t0['K1']
    K2 = df_t0['K2']
    S0 = df_t0['Adj_S0'].unique()
    # Adjustment of I_ref
    I_ref = 50
    d_S1, u_S1 = min(K1)-I_ref, max(K1)+I_ref
    d_S2, u_S2 = min(K2)-I_ref, max(K2)+I_ref
    while realS1 > u_S1:
        u_S1 += I_ref
    while realS1 < d_S1:
        d_S1 -= I_ref
    while realS2 > u_S2:
        u_S2 += I_ref
    while realS2 < d_S2:
        d_S2 -= I_ref
    S1 = np.linspace(d_S1, u_S1, N)
    S2 = np.linspace(d_S2, u_S2, N)
    
    m = gp.Model("Price Bounds")
    d = m.addVars(['d'], name="d")
    lamb1 = m.addVars(df_t0.index, name="lamb1")
    lamb2 = m.addVars(df_t0.index, name="lamb2")
    delta0 = m.addVars(['delta0'], name="delta0")
    delta1 = m.addVars(np.array(S1).flatten(), name="delta1")
    
    m.setObjective(d['d'] + 
                   sum(lamb1[r]*C1[r] for r in df_t0.index) + 
                   sum(lamb2[r]*C2[r] for r in df_t0.dropna().index))
        # in our cases the number of options at maturity T2 is less or equal to that at maturity T1
        # thus apply dropna() on T2 exclusively to shorten the running time effectively
    m.ModelSense = GRB.MINIMIZE
    
    for S1_i in S1:
        for S2_j in S2:
            m.addConstr(d['d'] + 
                        sum(lamb1[r]*max(S1_i-K1[r],0) for r in df_t0.index) + 
                        sum(lamb2[r]*max(S2_j-K2[r],0) for r in df_t0.dropna().index) + 
                        delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
                        >= payoff(S1_i, S2_j), 'C_{}{}'.format(S1_i, S2_j))
            m.update()
    
    m.optimize()
    
    if m.status == GRB.OPTIMAL:
        var = {v.varName: v.x for v in m.getVars()}
        
        delta1_values = np.array([var['delta1[{}]'.format(s1)] for s1 in S1])
        delta1_interpolator = CubicSpline(S1, delta1_values)
        
        parameters = {
            'd': var['d[d]'],
            'lamb1': {r: var['lamb1[{}]'.format(r)] for r in df_t0.index},
            'lamb2': {r: var['lamb2[{}]'.format(r)] for r in df_t0.dropna().index},
            'delta0': var['delta0[delta0]'],
            'delta1': delta1_interpolator
        }
    else:
        print("Optimization was not successful.")
        
    return parameters

# %%
def hedgingStrategy(parameters, df_t0):
    S0 = df_t0['Adj_S0'].unique()
    K1 = df_t0['K1']
    K2 = df_t0['K2']
    h = (parameters['d']
         + sum(parameters['lamb1'][r] * max(realS1-K1[r],0) for r in df_t0.index)
         + sum(parameters['lamb2'][r] * max(realS2-K2[r],0) for r in df_t0.dropna().index)
         + parameters['delta0'] * (realS1 - S0)
         + parameters['delta1'](realS1) * (realS2-realS1)
        )
    return h

# %%
# %%time
df_gap_S0 = pd.DataFrame()
df_gap_hedge = pd.DataFrame()

for filename in sorted(data_files):
    match = re.match(pattern, filename)
    ticker = match.group(1)
    date1 = match.group(2)
    date2 = match.group(3)
    t1 = f'{date1[:4]}-{date1[4:6]}-{date1[6:]}'
    t2 = f'{date2[:4]}-{date2[4:6]}-{date2[6:]}'

    path = data_path + '/' + filename
    df = pd.read_csv(path, index_col=0)
    t0List = list(df.t0.unique())
    
    realS1 = stocks.loc[stocks.Date==t1, ticker].item()
    realS2 = stocks.loc[stocks.Date==t2, ticker].item()
    
    gapList_S0 = []
    gapList_hedge = []
    for t0 in t0List:
        df_t0 = df.loc[df.t0 == t0].copy()
        
        parameters = params(df_t0, N)
        h = hedgingStrategy(parameters, df_t0)
        
        S0 = df_t0['Adj_S0'].unique()
        gap_S0 = (h - payoff(realS1, realS2)) / S0
        gap_hedge = (h - payoff(realS1, realS2)) / h
        
        gapList_S0.append(gap_S0.item())
        gapList_hedge.append(gap_hedge.item())

    distance_to_t1 = np.busday_count(pd.to_datetime(t0List).values.astype('datetime64[D]'), 
                                     pd.to_datetime([t1]).values.astype('datetime64[D]'))
    tmp_S0 = pd.DataFrame(np.array(gapList_S0), columns=[filename[:-4]], index=distance_to_t1)
    tmp_hedge = pd.DataFrame(np.array(gapList_hedge), columns=[filename[:-4]], index=distance_to_t1)
    df_gap_S0 = pd.concat([df_gap_S0, tmp_S0.T])
    df_gap_hedge = pd.concat([df_gap_hedge, tmp_hedge.T])
# Out:
# Restricted license - for non-production use only - expires 2025-11-24
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10340 nonzeros
# Model fingerprint: 0x0674794c
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 3e+02]
# Presolve removed 80 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 320 rows, 57 columns, 7748 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.289441e+03   0.000000e+00      0s
#       28    8.7735581e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 28 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.773558102e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10139 nonzeros
# Model fingerprint: 0x979d4440
# Coefficient statistics:
#   Matrix range     [5e-01, 5e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 10099 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.478289e+03   0.000000e+00      0s
#       39    8.9291209e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.929120921e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9259 nonzeros
# Model fingerprint: 0xd49cc382
# Coefficient statistics:
#   Matrix range     [2e-13, 4e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 2e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8616 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.220395e+02   0.000000e+00      0s
#       18    9.5538602e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.553860243e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10640 nonzeros
# Model fingerprint: 0x6f97e0f0
# Coefficient statistics:
#   Matrix range     [4e-02, 6e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.262303e+03   0.000000e+00      0s
#       60    6.4733878e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 60 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  6.473387769e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10799 nonzeros
# Model fingerprint: 0x4935f181
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [9e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 10768 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.220880e+03   0.000000e+00      0s
#       54    4.7284043e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.728404299e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11440 nonzeros
# Model fingerprint: 0x9fcf09a7
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 6e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 11086 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.792212e+03   0.000000e+00      0s
#       52    6.6998382e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 52 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.699838250e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10280 nonzeros
# Model fingerprint: 0x6dfccccc
# Coefficient statistics:
#   Matrix range     [2e-13, 6e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-13, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 10263 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.947368e+03   0.000000e+00      0s
#       49    9.3880968e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.388096771e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10680 nonzeros
# Model fingerprint: 0x59863da9
# Coefficient statistics:
#   Matrix range     [2e-13, 5e+02]
#   Objective range  [3e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10680 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.231398e+03   0.000000e+00      0s
#       44    6.8548635e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 44 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.854863496e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9980 nonzeros
# Model fingerprint: 0xff77bb64
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9980 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.126579e+03   0.000000e+00      0s
#       58    9.1562903e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.156290268e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10480 nonzeros
# Model fingerprint: 0x5d37d38b
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [1e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.514194e+03   0.000000e+00      0s
#       70    6.6413704e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 70 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  6.641370410e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9380 nonzeros
# Model fingerprint: 0xae44c500
# Coefficient statistics:
#   Matrix range     [1e-01, 4e+02]
#   Objective range  [5e-03, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.586579e+03   0.000000e+00      0s
#       41    7.7628243e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 41 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  7.762824307e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10878 nonzeros
# Model fingerprint: 0x63f3acf2
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [6e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 3e+02]
# Presolve removed 201 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 199 rows, 49 columns, 4550 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.134868e+02   0.000000e+00      0s
#       14    6.5616823e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  6.561682320e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11740 nonzeros
# Model fingerprint: 0x54be6595
# Coefficient statistics:
#   Matrix range     [2e-13, 4e+02]
#   Objective range  [4e-01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 4e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 11428 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.478010e+03   0.000000e+00      0s
#       34    4.1506397e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.150639715e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9899 nonzeros
# Model fingerprint: 0x67684728
# Coefficient statistics:
#   Matrix range     [5e-01, 4e+02]
#   Objective range  [1e+00, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 9877 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.651809e+03   0.000000e+00      0s
#       62    5.2063377e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 62 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.206337684e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11240 nonzeros
# Model fingerprint: 0x24346107
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [4e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve removed 140 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 260 rows, 54 columns, 6797 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.201645e+02   0.000000e+00      0s
#       26    8.4225420e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.422542029e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12059 nonzeros
# Model fingerprint: 0xc9ddbd05
# Coefficient statistics:
#   Matrix range     [5e-01, 5e+02]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 4e+02]
# Presolve removed 81 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 319 rows, 57 columns, 9194 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.976086e+03   0.000000e+00      0s
#       31    5.1283760e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.128375973e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12260 nonzeros
# Model fingerprint: 0xc1665076
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [5e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 12260 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.671053e+03   0.000000e+00      0s
#       39    4.7470903e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  4.747090277e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11500 nonzeros
# Model fingerprint: 0x37ac986b
# Coefficient statistics:
#   Matrix range     [8e-01, 5e+02]
#   Objective range  [2e-01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 5e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 11195 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.156530e+03   0.000000e+00      0s
#       35    4.0405701e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.040570084e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10580 nonzeros
# Model fingerprint: 0x9f63bfc3
# Coefficient statistics:
#   Matrix range     [3e-01, 4e+02]
#   Objective range  [9e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 4e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10580 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.958717e+03   0.000000e+00      0s
#       52    5.4989172e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 52 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.498917224e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9420 nonzeros
# Model fingerprint: 0x005a1e1f
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [6e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9420 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.745099e+03   0.000000e+00      0s
#       24    7.1800000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  7.180000000e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10480 nonzeros
# Model fingerprint: 0xb6da50bc
# Coefficient statistics:
#   Matrix range     [3e-01, 3e+02]
#   Objective range  [1e-01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 3e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.895304e+03   0.000000e+00      0s
#       55    4.1624344e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 55 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  4.162434417e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9840 nonzeros
# Model fingerprint: 0xfa02a6a0
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+02]
#   Objective range  [5e-03, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-01, 2e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9840 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.909992e+03   0.000000e+00      0s
#       54    4.1951083e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  4.195108332e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8240 nonzeros
# Model fingerprint: 0xbb3a1d36
# Coefficient statistics:
#   Matrix range     [1e-01, 1e+03]
#   Objective range  [3e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 4e+02]
# Presolve removed 300 rows and 34 columns
# Presolve time: 0.00s
# Presolved: 100 rows, 28 columns, 775 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.063980e+02   0.000000e+00      0s
#       13    8.9127424e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.912742382e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8299 nonzeros
# Model fingerprint: 0xc297937f
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 5e+02]
# Presolve removed 81 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 319 rows, 57 columns, 6523 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.759901e+03   0.000000e+00      0s
#       37    9.8504430e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 37 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.850442964e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8000 nonzeros
# Model fingerprint: 0x53efe4db
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 8000 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.241365e+03   0.000000e+00      0s
#       49    1.0895861e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  1.089586141e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10940 nonzeros
# Model fingerprint: 0x411b5def
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+03]
#   Objective range  [9e-02, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 8e+02]
# Presolve removed 180 rows and 10 columns
# Presolve time: 0.00s
# Presolved: 220 rows, 52 columns, 5232 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.019441e+03   0.000000e+00      0s
#       21    1.3741175e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 21 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.374117472e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10920 nonzeros
# Model fingerprint: 0x0d7cfb68
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [2e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 140 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 260 rows, 54 columns, 6343 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.100855e+03   0.000000e+00      0s
#       33    1.0822794e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.082279422e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9040 nonzeros
# Model fingerprint: 0x94203573
# Coefficient statistics:
#   Matrix range     [5e-01, 9e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 9e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9040 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.699770e+03   0.000000e+00      0s
#       54    1.0149122e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  1.014912180e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9938 nonzeros
# Model fingerprint: 0xea6ef864
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [7e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 5e+02]
# Presolve removed 120 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 280 rows, 55 columns, 6476 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.760526e+03   0.000000e+00      0s
#       22    7.2528268e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  7.252826783e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10620 nonzeros
# Model fingerprint: 0x349dfbd9
# Coefficient statistics:
#   Matrix range     [3e-01, 9e+02]
#   Objective range  [5e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 9e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10620 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.667426e+03   0.000000e+00      0s
#       49    7.1309317e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  7.130931743e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10479 nonzeros
# Model fingerprint: 0x6398c238
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve removed 41 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 359 rows, 60 columns, 9835 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.685625e+03   0.000000e+00      0s
#       50    6.0405641e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 50 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  6.040564129e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11659 nonzeros
# Model fingerprint: 0xb1dc75d5
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [4e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve removed 19 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 381 rows, 61 columns, 11335 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.985378e+03   0.000000e+00      0s
#       29    3.1492868e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.149286820e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11420 nonzeros
# Model fingerprint: 0x01cca2c7
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve removed 240 rows and 13 columns
# Presolve time: 0.00s
# Presolved: 160 rows, 49 columns, 3840 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.757566e+02   0.000000e+00      0s
#       22    1.1004004e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.100400449e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11860 nonzeros
# Model fingerprint: 0x2e8fa189
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [1e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 260 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 140 rows, 48 columns, 3783 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.787500e+02   0.000000e+00      0s
#       26    6.6536702e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  6.653670214e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10616 nonzeros
# Model fingerprint: 0xb8e0b534
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [3e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 5e+02]
# Presolve removed 22 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 378 rows, 61 columns, 10244 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.831579e+03   0.000000e+00      0s
#       29    4.8331838e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  4.833183794e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 13560 nonzeros
# Model fingerprint: 0x66253da8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [5e-03, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 80 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 320 rows, 57 columns, 10640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.997747e+03   0.000000e+00      0s
#       29    6.5217027e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.521702681e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9820 nonzeros
# Model fingerprint: 0x055fbc2d
# Coefficient statistics:
#   Matrix range     [3e-01, 4e+02]
#   Objective range  [1e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 360 rows, 60 columns, 9302 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.213569e+03   0.000000e+00      0s
#       26    4.5092904e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  4.509290445e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10640 nonzeros
# Model fingerprint: 0x23cd901e
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [6e-02, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 8e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.617105e+03   0.000000e+00      0s
#       58    1.1583413e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.158341316e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 13120 nonzeros
# Model fingerprint: 0xa4dd40e0
# Coefficient statistics:
#   Matrix range     [8e-01, 7e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+02]
# Presolve removed 400 rows and 62 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9400 nonzeros
# Model fingerprint: 0xccf53de1
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9400 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.927961e+03   0.000000e+00      0s
#       35    1.7297238e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.729723835e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9459 nonzeros
# Model fingerprint: 0x543bf37d
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 8e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 9445 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.639408e+03   0.000000e+00      0s
#       33    6.9147949e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  6.914794949e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11260 nonzeros
# Model fingerprint: 0x1439d0b7
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 8e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 360 rows, 60 columns, 10688 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.547220e+03   0.000000e+00      0s
#       27    8.1515377e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  8.151537659e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11600 nonzeros
# Model fingerprint: 0x67a2ee59
# Coefficient statistics:
#   Matrix range     [7e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 8e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 360 rows, 60 columns, 10954 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.685855e+03   0.000000e+00      0s
#       32    7.9826794e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  7.982679404e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10800 nonzeros
# Model fingerprint: 0x927c1af6
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10800 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.557418e+03   0.000000e+00      0s
#       34    1.2503804e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.250380430e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10455 nonzeros
# Model fingerprint: 0x286e601c
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 8e+02]
# Presolve removed 23 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 377 rows, 61 columns, 10082 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.909868e+03   0.000000e+00      0s
#       27    7.9335252e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  7.933525170e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10780 nonzeros
# Model fingerprint: 0x0b2a3615
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10780 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.454523e+03   0.000000e+00      0s
#       36    1.2294374e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.229437392e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12380 nonzeros
# Model fingerprint: 0x4d4c3fdc
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 9e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 12380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.529638e+03   0.000000e+00      0s
#       27    8.0437996e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  8.043799633e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11899 nonzeros
# Model fingerprint: 0x36506ed3
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 9e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 399 rows, 62 columns, 11859 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.190921e+03   0.000000e+00      0s
#       32    1.0068832e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.006883152e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11940 nonzeros
# Model fingerprint: 0xbae7b7e4
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 7e+02]
# Presolve removed 40 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 360 rows, 59 columns, 10536 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.145559e+03   0.000000e+00      0s
#       35    9.9823994e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.982399382e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12740 nonzeros
# Model fingerprint: 0x19aef731
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 12740 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.865707e+03   0.000000e+00      0s
#       32    1.0303952e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  1.030395225e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11500 nonzeros
# Model fingerprint: 0xc7a270ec
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [8e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 11500 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.124424e+03   0.000000e+00      0s
#       30    1.1467758e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 30 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.146775767e+02
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9979 nonzeros
# Model fingerprint: 0x3ebcaa9e
# Coefficient statistics:
#   Matrix range     [5e-01, 5e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 5e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9979 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.219046e+03   0.000000e+00      0s
#       41    8.9406457e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 41 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.940645653e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10820 nonzeros
# Model fingerprint: 0x68251aca
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10820 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.397961e+03   0.000000e+00      0s
#       49    8.0080511e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  8.008051077e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12380 nonzeros
# Model fingerprint: 0xe8dc6039
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [4e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 7e+02]
# Presolve removed 160 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 240 rows, 53 columns, 7008 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.186760e+03   0.000000e+00      0s
#       33    9.2581119e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.258111932e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12559 nonzeros
# Model fingerprint: 0x90054a32
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [3e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 9e+02]
# Presolve removed 81 rows and 5 columns
# Presolve time: 0.00s
# Presolved: 319 rows, 57 columns, 9773 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.859013e+03   0.000000e+00      0s
#       39    8.5282890e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.528288999e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 12800 nonzeros
# Model fingerprint: 0x86a3b9c4
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [1e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 12472 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.994441e+03   0.000000e+00      0s
#       28    6.8261475e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 28 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.826147529e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 11080 nonzeros
# Model fingerprint: 0xfe467ffd
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [3e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 11080 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.943503e+03   0.000000e+00      0s
#       51    7.2915776e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 51 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  7.291577551e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 10740 nonzeros
# Model fingerprint: 0xa722c35d
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10740 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.609441e+03   0.000000e+00      0s
#       51    9.0496269e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 51 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.049626880e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# ...
#       46    3.7368663e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 46 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.736866254e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9239 nonzeros
# Model fingerprint: 0x27614f4f
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [1e-02, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8573 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.326086e+03   0.000000e+00      0s
#       35    3.7234754e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.723475373e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8919 nonzeros
# Model fingerprint: 0x104e90f1
# Coefficient statistics:
#   Matrix range     [2e-01, 2e+02]
#   Objective range  [1e-02, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8268 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.7142592e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.714259163e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9539 nonzeros
# Model fingerprint: 0xc923e14e
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [1e-02, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8872 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       36    3.7291625e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.729162518e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8979 nonzeros
# Model fingerprint: 0x878435f1
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [1e-02, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8321 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       36    3.7287153e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.728715311e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9319 nonzeros
# Model fingerprint: 0x35cb4be8
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8656 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.6491438e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.649143783e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8959 nonzeros
# Model fingerprint: 0x1320de61
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8302 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.6964261e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.696426051e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9300 nonzeros
# Model fingerprint: 0xf2c42de0
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 352 rows, 60 columns, 8054 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       32    3.5405004e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.540500408e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9099 nonzeros
# Model fingerprint: 0xf1325050
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8438 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.6563969e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.656396910e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9099 nonzeros
# Model fingerprint: 0x424c5108
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8443 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       42    3.6388232e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.638823230e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9239 nonzeros
# Model fingerprint: 0xb84e6c90
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8571 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       42    3.5414222e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.541422202e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9400 nonzeros
# Model fingerprint: 0x057db9ff
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 352 rows, 60 columns, 8136 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.4120124e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.412012384e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9159 nonzeros
# Model fingerprint: 0xee2d6757
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8496 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       41    3.5840033e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 41 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.584003343e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9219 nonzeros
# Model fingerprint: 0x4e5664f5
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8557 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.5796100e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.579609970e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9080 nonzeros
# Model fingerprint: 0xc7934f8c
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 352 rows, 60 columns, 7842 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.4256172e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.425617233e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 8800 nonzeros
# Model fingerprint: 0x448d6a5a
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 2e+02]
# Presolve removed 80 rows and 4 columns
# Presolve time: 0.00s
# Presolved: 320 rows, 58 columns, 7008 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.099095e+03   0.000000e+00      0s
#       31    3.0457348e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  3.045734790e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9419 nonzeros
# Model fingerprint: 0x77b209f9
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8746 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.5634602e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.563460239e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9120 nonzeros
# Model fingerprint: 0xd6fb74d3
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 2e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 360 rows, 60 columns, 7826 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.177895e+03   0.000000e+00      0s
#       33    3.4946342e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.494634163e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9140 nonzeros
# Model fingerprint: 0x901af6e8
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 60 columns, 7894 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.3802477e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.380247678e+01
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 400 rows, 62 columns and 9520 nonzeros
# Model fingerprint: 0xba7b85d1
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 352 rows, 60 columns, 8243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.3633065e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.00 seconds (0.01 work units)
# Optimal objective  3.363306502e+01
# CPU times: user 4min 15s, sys: 9.69 s, total: 4min 24s
# Wall time: 4min 22s

# %%
df_gap_S0 = df_gap_S0.sort_index(axis=1).copy()
df_gap_S0.head()
# Out:
#                              0         1         2         3         4    \
# AMZN_20180706_20180803  0.006749  0.003605       NaN  0.014900  0.000814
# AMZN_20191206_20200103  0.000539  0.000687  0.011082  0.000379  0.004953
# AMZN_20200306_20200403  0.045877  0.014193  0.020218  0.020720  0.024628
# AMZN_20200409_20200501  0.009652  0.001978  0.001588  0.006261  0.022238
# AMZN_20200612_20200702 -0.000010  0.009997  0.125135  0.010681  0.002750
#
#                              5         6         7         8         9    ...  \
# AMZN_20180706_20180803  0.014110  0.003064  0.019863  0.006767  0.007710  ...
# AMZN_20191206_20200103  0.002230       NaN  0.004678  0.010033  0.000144  ...
# AMZN_20200306_20200403  0.039670  0.022709  0.009261  0.019000  0.016185  ...
# AMZN_20200409_20200501  0.016556  0.022318  0.005413  0.012470  0.028460  ...
# AMZN_20200612_20200702  0.002758  0.002686  0.003393  0.003449  0.004733  ...
#
#                         245  246  247  250  251  252  253  255  256  257
# AMZN_20180706_20180803  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20191206_20200103  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20200306_20200403  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20200409_20200501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20200612_20200702  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 246 columns]

# %%
df_gap_hedge = df_gap_hedge.sort_index(axis=1).copy()
df_gap_hedge.head()
# Out:
#                              0         1         2         3         4    \
# AMZN_20180706_20180803  0.092946  0.051578       NaN  0.183027  0.012238
# AMZN_20191206_20200103  0.007594  0.009596  0.136558  0.005411  0.066755
# AMZN_20200306_20200403  0.940679  0.832359  0.878979  0.877922  0.897429
# AMZN_20200409_20200501  0.074969  0.016342  0.012957  0.048898  0.148416
# AMZN_20200612_20200702 -0.000072  0.068956  0.489661  0.074465  0.019706
#
#                              5         6         7         8         9    ...  \
# AMZN_20180706_20180803  0.175521  0.044233  0.226461  0.092204  0.102184  ...
# AMZN_20191206_20200103  0.031524       NaN  0.064513  0.127502  0.002061  ...
# AMZN_20200306_20200403  0.931446  0.886106  0.769227  0.872038  0.855342  ...
# AMZN_20200409_20200501  0.115501  0.148940  0.041579  0.091461  0.181857  ...
# AMZN_20200612_20200702  0.019447  0.018779  0.023776  0.024104  0.032761  ...
#
#                         245  246  247  250  251  252  253  255  256  257
# AMZN_20180706_20180803  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20191206_20200103  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20200306_20200403  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20200409_20200501  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# AMZN_20200612_20200702  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 246 columns]

# %%
plt.plot(df_gap_S0.mean())
plt.xlabel('distance to t1')
plt.ylabel('mean of gaps')
plt.title('normalising by S0')
plt.ylim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
plt.plot(df_gap_S0.median())
plt.xlabel('distance to t1')
plt.ylabel('median of gaps')
plt.title('normalising by S0')
plt.ylim(-0.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
df_gap_S0[[0, 1, 2, 3]].hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
df_gap_S0[[40, 41, 42, 43]].hist()
# Out:
# array([[<Axes: title={'center': '40'}>, <Axes: title={'center': '41'}>],
#        [<Axes: title={'center': '42'}>, <Axes: title={'center': '43'}>]],
#       dtype=object)

# %%
df_gap_S0[[13, 19]].hist()  # kind of outliers
# Out:
# array([[<Axes: title={'center': '13'}>, <Axes: title={'center': '19'}>]],
#       dtype=object)

# %%
plt.plot(df_gap_hedge.mean())
plt.xlabel('distance to t1')
plt.ylabel('mean of gaps')
plt.title('normalising by hedge value')
plt.ylim(0.6, 1.05)
# Out:
# (0.6, 1.05)

# %%
plt.plot(df_gap_hedge.median())
plt.xlabel('distance to t1')
plt.ylabel('median of gaps')
plt.title('normalising by hedge value')
plt.ylim(0.6, 1.05)
# Out:
# (0.6, 1.05)

# %%
df_gap_hedge[[0, 1, 2, 3]].hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
df_gap_hedge[[40, 41, 42, 43]].hist()
# Out:
# array([[<Axes: title={'center': '40'}>, <Axes: title={'center': '41'}>],
#        [<Axes: title={'center': '42'}>, <Axes: title={'center': '43'}>]],
#       dtype=object)

# %%
df_gap_S0.to_csv('gap_1MonthT1T2_S0.csv')
df_gap_hedge.to_csv('gap_1MonthT1T2_hedge.csv')
