# %%
import pandas as pd
import numpy as np
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt

# %%
import gurobipy as gp
from gurobipy import GRB

options = {
    "WLSACCESSID": "31598bc4-0b23-474f-86d4-af032d437137",
    "WLSSECRET": "bd7ad348-f8d6-452e-b615-ebc88d920e41",
    "LICENSEID": 2498404,
}

# %% [markdown]
# ### Linear Programming Problem
# min $d+\sum_{n=1}^{N_1}\lambda_{n,1}\Pi_{n,1}+\sum_{n=1}^{N_2}\lambda_{n,2}\Pi_{n,2}$
#
# s.t. $d+\sum_{n=1}^{N_1}\lambda_{n,1}(S_1^i-K_{n,1})^++\sum_{n=1}^{N_2}\lambda_{n,2}(S_2^j-K_{n,2})^++\Delta_{0}\cdot(S_1^i-S_0)+\Delta_{1}^i\cdot(S_2^j-S_1^i) \geq \Phi(S_1^i,S_2^j), i,j=1,...,N$

# %%
def payoff(S1,S2):
    return max(S2 - S1, 0)

# %% [markdown]
# ### Gap for fixed T2-T2 difference
# For all stocks and fixed 1 month difference between T1 and T2

# %%
import os
def read_all_paths(directory):
    all_paths = []
    for root, dirs, files in os.walk(directory):
        for name in files:
            file_path = os.path.join(root, name)
            all_paths.append(file_path)
        for name in dirs:
            dir_path = os.path.join(root, name)
            all_paths.append(dir_path)
    return all_paths
def payoff(S1,S2):
    return max(S2 - S1, 0)

directory_path = 'data/paired_Option/'  
paths = read_all_paths(directory_path)
if 'data/paired_Option/.ipynb_checkpoints' in paths:
    paths.remove('data/paired_Option/.ipynb_checkpoints')
gap_T1 = pd.DataFrame()
I_ref = 50
N = 20
for path in paths:
    df = pd.read_csv(path, index_col=0)
    path = path.split('.')[0]
    path = path.split('/')[-1]
    t1 = pd.to_datetime(path.split('_')[1])
    t2 = pd.to_datetime(path.split('_')[2])
    t0List = list(df.t0.unique())
    stocks = pd.read_csv('data/adjusted_Stock_Daily/{}_stock_daily_adjusted.csv'.format(path.split('_')[0].lower()),index_col=0)
    stocks['date'] = pd.to_datetime(stocks['date'])
    realS1 = stocks.loc[stocks.date==t1, 'adjusted_price'].item()
    realS2 = stocks.loc[stocks.date==t2, 'adjusted_price'].item()
    
    parameters = {}
    hList = []
    for t0 in t0List:
        df_t0 = df.loc[df.t0 == t0].dropna().copy()

        C1 = df_t0['C1']
        C2 = df_t0['C2']
        K1 = df_t0['K1']
        K2 = df_t0['K2']
        
        S0 = df_t0['Adj_S0'].unique()
        S1 = np.linspace(min(K1)-I_ref, max(K1)+I_ref, N)
        S2 = np.linspace(min(K2)-I_ref, max(K2)+I_ref, N)

        m = gp.Model("Price Bounds")
        d = m.addVars(['d'], name="d")
        lamb1 = m.addVars(df_t0.index, name="lamb1")
        lamb2 = m.addVars(df_t0.index, name="lamb2")
        delta0 = m.addVars(['delta0'], name="delta0")
        delta1 = m.addVars(np.array(S1).flatten(), name="delta1")

        m.setObjective(d['d']+sum(lamb1[r]*C1[r]+lamb2[r]*C2[r] for r in df_t0.index))
        m.ModelSense = GRB.MINIMIZE

        for S1_i in S1:
            for S2_j in S2:
                m.addConstr(d['d'] + sum(lamb1[r]*max(S1_i-K1[r],0)+lamb2[r]*max(S2_j-K2[r],0) for r in df_t0.index) + 
                            delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
                            >= payoff(S1_i, S2_j), 'C_{}{}'.format(S1_i, S2_j))
                m.update()

        m.optimize()

        if m.status == GRB.OPTIMAL:
            var = {v.varName: v.x for v in m.getVars()}

            delta1_values = np.array([var['delta1[{}]'.format(s1)] for s1 in S1])
            delta1_interpolator = CubicSpline(S1, delta1_values)

            parameters[t0] = {
                'd': var['d[d]'],
                'lamb1': {r: var['lamb1[{}]'.format(r)] for r in df_t0.index},
                'lamb2': {r: var['lamb2[{}]'.format(r)] for r in df_t0.index},
                'delta0': var['delta0[delta0]'],
                'delta1': delta1_interpolator
            }
        else:
            print("Optimization was not successful.")
    
        h = (parameters[t0]['d']
             + sum(parameters[t0]['lamb1'][r] * max(realS1-K1[r],0) + 
                   parameters[t0]['lamb2'][r] * max(realS2-K2[r],0) for r in df_t0.index)
             + parameters[t0]['delta0'] * (realS1 - S0)
             + parameters[t0]['delta1'](realS1) * (realS2-realS1)
            )
        hList.append(h)
    
    h_minus_c = (np.array(hList).flatten() - payoff(realS1, realS2))/(np.abs(payoff(realS1, realS2))+1)
    h_minus_c
    timeToMaturity = np.busday_count(pd.to_datetime(t0List).values.astype('datetime64[D]'),pd.to_datetime([t1]).values.astype('datetime64[D]'))

    df_gap = pd.DataFrame(h_minus_c,columns=[path],index=timeToMaturity)
#     import pdb
#     pdb.set_trace()
    gap_T1 = pd.concat([gap_T1,df_gap.T])
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10340 nonzeros
# Model fingerprint: 0x15c21522
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 3e+02]
# Presolve removed 80 rows and 5 columns
# Presolve time: 0.01s
# Presolved: 320 rows, 57 columns, 7748 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.289441e+03   0.000000e+00      0s
#       28    8.7735581e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 28 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.773558102e+01
# C:\Users\yanhui\AppData\Local\Temp\ipykernel_12520\384558770.py:61: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10139 nonzeros
# Model fingerprint: 0x3e583ed2
# Coefficient statistics:
#   Matrix range     [5e-01, 5e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 399 rows, 62 columns, 10099 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.478289e+03   0.000000e+00      0s
#       39    8.9291209e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.929120921e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 8639 nonzeros
# Model fingerprint: 0xcd42e670
# Coefficient statistics:
#   Matrix range     [2e-13, 4e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 2e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 80 rows and 5 columns
# Presolve time: 0.01s
# Presolved: 320 rows, 57 columns, 6191 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.134868e+02   0.000000e+00      0s
#       14    8.7495053e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.749505342e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10640 nonzeros
# Model fingerprint: 0x6f97e0f0
# Coefficient statistics:
#   Matrix range     [4e-02, 6e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.262303e+03   0.000000e+00      0s
#       60    6.4733878e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 60 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.473387769e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10799 nonzeros
# Model fingerprint: 0x2fae5487
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [9e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 6e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 399 rows, 62 columns, 10768 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.220880e+03   0.000000e+00      0s
#       54    4.7284043e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.728404299e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11440 nonzeros
# Model fingerprint: 0x9fcf09a7
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 6e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 11086 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.792212e+03   0.000000e+00      0s
#       52    6.6998382e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 52 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.699838250e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10280 nonzeros
# Model fingerprint: 0x6dfccccc
# Coefficient statistics:
#   Matrix range     [2e-13, 7e+02]
#   Objective range  [4e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-13, 6e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 399 rows, 62 columns, 10263 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.947368e+03   0.000000e+00      0s
#       49    9.3880968e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 49 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  9.388096771e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10680 nonzeros
# Model fingerprint: 0x1b2a64ca
# Coefficient statistics:
#   Matrix range     [2e-13, 5e+02]
#   Objective range  [3e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10680 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.231398e+03   0.000000e+00      0s
#       44    6.8548635e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 44 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  6.854863496e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9980 nonzeros
# Model fingerprint: 0xcd77f615
# Coefficient statistics:
#   Matrix range     [3e-01, 6e+02]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 9980 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.126579e+03   0.000000e+00      0s
#       58    9.1562903e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.156290268e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10480 nonzeros
# Model fingerprint: 0x5d37d38b
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [1e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.514194e+03   0.000000e+00      0s
#       70    6.6413704e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 70 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  6.641370410e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9380 nonzeros
# Model fingerprint: 0xd3056280
# Coefficient statistics:
#   Matrix range     [1e-01, 4e+02]
#   Objective range  [5e-03, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 9380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.586579e+03   0.000000e+00      0s
#       41    7.7628243e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 41 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.762824307e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10878 nonzeros
# Model fingerprint: 0xe0bf0835
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [6e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 3e+02]
# Presolve removed 201 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 199 rows, 49 columns, 4550 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.134868e+02   0.000000e+00      0s
#       14    6.5616823e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.561682320e+01
# C:\Users\yanhui\AppData\Local\Temp\ipykernel_12520\384558770.py:61: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11740 nonzeros
# Model fingerprint: 0x54be6595
# Coefficient statistics:
#   Matrix range     [2e-13, 4e+02]
#   Objective range  [4e-01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 4e+02]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 11428 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.478010e+03   0.000000e+00      0s
#       34    4.1506397e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  4.150639715e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9899 nonzeros
# Model fingerprint: 0x9d817647
# Coefficient statistics:
#   Matrix range     [5e-01, 4e+02]
#   Objective range  [1e+00, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 4e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 399 rows, 62 columns, 9877 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.651809e+03   0.000000e+00      0s
#       62    5.2063377e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 62 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.206337684e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11240 nonzeros
# Model fingerprint: 0x8bdb3802
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [4e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve removed 140 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 260 rows, 54 columns, 6797 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.201645e+02   0.000000e+00      0s
#       26    8.4225420e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.422542029e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 12059 nonzeros
# Model fingerprint: 0x51b65712
# Coefficient statistics:
#   Matrix range     [5e-01, 5e+02]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 4e+02]
# Presolve removed 81 rows and 5 columns
# Presolve time: 0.01s
# Presolved: 319 rows, 57 columns, 9194 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.976086e+03   0.000000e+00      0s
#       31    5.1283760e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.128375973e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 12260 nonzeros
# Model fingerprint: 0x0491f594
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [5e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 12260 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.671053e+03   0.000000e+00      0s
#       39    4.7470903e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 39 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.747090277e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11500 nonzeros
# Model fingerprint: 0x924d7a1c
# Coefficient statistics:
#   Matrix range     [8e-01, 5e+02]
#   Objective range  [2e-01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 5e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 11195 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.156530e+03   0.000000e+00      0s
#       35    4.0405701e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.040570084e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10580 nonzeros
# Model fingerprint: 0xf4498d61
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [9e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10580 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.958717e+03   0.000000e+00      0s
#       52    5.4989172e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 52 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.498917224e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9420 nonzeros
# Model fingerprint: 0xca321f3e
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [6e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 3e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 9420 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.745099e+03   0.000000e+00      0s
#       24    7.1800000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.180000000e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10480 nonzeros
# Model fingerprint: 0x918fdbcf
# Coefficient statistics:
#   Matrix range     [3e-01, 3e+02]
#   Objective range  [1e-01, 5e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 3e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10480 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.895304e+03   0.000000e+00      0s
#       55    4.1624344e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 55 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  4.162434417e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9840 nonzeros
# Model fingerprint: 0xc3a45fce
# Coefficient statistics:
#   Matrix range     [2e-02, 3e+02]
#   Objective range  [5e-03, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-01, 3e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 9840 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.909992e+03   0.000000e+00      0s
#       54    4.1951083e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.195108332e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11000 nonzeros
# Model fingerprint: 0xb1fd94df
# Coefficient statistics:
#   Matrix range     [4e-01, 1e+03]
#   Objective range  [3e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 2e+02]
# Presolve removed 340 rows and 34 columns
# Presolve time: 0.01s
# Presolved: 60 rows, 28 columns, 847 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.938651e+02   0.000000e+00      0s
#        9    3.7594569e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.759456901e+01
# C:\Users\yanhui\AppData\Local\Temp\ipykernel_12520\384558770.py:61: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9460 nonzeros
# Model fingerprint: 0x7b0f9534
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 4e+02]
# Presolve removed 60 rows and 4 columns
# Presolve time: 0.01s
# Presolved: 340 rows, 58 columns, 7555 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.361612e+03   0.000000e+00      0s
#       30    9.8574401e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 30 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.857440106e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10799 nonzeros
# Model fingerprint: 0x64016d93
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [1e+00, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 60 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 340 rows, 59 columns, 9842 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.209868e+03   0.000000e+00      0s
#       30    5.7758688e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 30 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  5.775868843e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11819 nonzeros
# Model fingerprint: 0xddc80a81
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+03]
#   Objective range  [9e-02, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 6e+02]
# Presolve removed 221 rows and 12 columns
# Presolve time: 0.01s
# Presolved: 179 rows, 50 columns, 4806 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.484539e+02   0.000000e+00      0s
#       14    1.1733923e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.173392294e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 13080 nonzeros
# Model fingerprint: 0x23cedaaf
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [2e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 6e+02]
# Presolve removed 180 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 220 rows, 52 columns, 6969 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.501859e+03   0.000000e+00      0s
#       25    5.9723320e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  5.972332025e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10520 nonzeros
# Model fingerprint: 0xff41ce8e
# Coefficient statistics:
#   Matrix range     [5e-01, 9e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-01, 7e+02]
# Presolve time: 0.00s
# Presolved: 400 rows, 62 columns, 10520 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.679803e+03   0.000000e+00      0s
#       48    9.8295520e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 48 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.829552019e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10340 nonzeros
# Model fingerprint: 0xf5736575
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [7e-01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 5e+02]
# Presolve removed 100 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 300 rows, 56 columns, 7155 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.678454e+03   0.000000e+00      0s
#       30    7.2521057e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 30 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  7.252105686e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11780 nonzeros
# Model fingerprint: 0x784d22f4
# Coefficient statistics:
#   Matrix range     [3e-01, 8e+02]
#   Objective range  [5e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 8e+02]
# Presolve removed 400 rows and 62 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11120 nonzeros
# Model fingerprint: 0x4602125c
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 6e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 11120 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.959770e+03   0.000000e+00      0s
#       60    6.0454317e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 60 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.045431743e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11659 nonzeros
# Model fingerprint: 0x67044756
# Coefficient statistics:
#   Matrix range     [5e-01, 6e+02]
#   Objective range  [4e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve removed 19 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 381 rows, 61 columns, 11335 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.985378e+03   0.000000e+00      0s
#       29    3.1492868e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.149286820e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11420 nonzeros
# Model fingerprint: 0x2b5eedb8
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e-02, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 6e+02]
# Presolve removed 240 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 160 rows, 49 columns, 3840 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.757566e+02   0.000000e+00      0s
#       22    1.1004004e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.100400449e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11860 nonzeros
# Model fingerprint: 0x6caa6dba
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [1e-02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Presolve removed 260 rows and 14 columns
# Presolve time: 0.01s
# Presolved: 140 rows, 48 columns, 3783 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.787500e+02   0.000000e+00      0s
#       26    6.6536702e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  6.653670214e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10616 nonzeros
# Model fingerprint: 0x52a68bd3
# Coefficient statistics:
#   Matrix range     [3e-01, 5e+02]
#   Objective range  [3e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 5e+02]
# Presolve removed 22 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 378 rows, 61 columns, 10244 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.831579e+03   0.000000e+00      0s
#       29    4.8331838e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  4.833183794e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 13560 nonzeros
# Model fingerprint: 0x9aa87353
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [5e-03, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve removed 80 rows and 5 columns
# Presolve time: 0.01s
# Presolved: 320 rows, 57 columns, 10640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.997747e+03   0.000000e+00      0s
#       29    6.5217027e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 29 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.521702681e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9820 nonzeros
# Model fingerprint: 0x055fbc2d
# Coefficient statistics:
#   Matrix range     [3e-01, 4e+02]
#   Objective range  [1e-01, 9e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 4e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 360 rows, 60 columns, 9302 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.213569e+03   0.000000e+00      0s
#       26    4.5092904e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 26 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  4.509290445e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10640 nonzeros
# Model fingerprint: 0x4eae7004
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [6e-02, 3e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 8e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10640 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.617105e+03   0.000000e+00      0s
#       58    1.1583413e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.158341316e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10500 nonzeros
# Model fingerprint: 0xd94f473e
# Coefficient statistics:
#   Matrix range     [3e-01, 7e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 3e+02]
# Presolve removed 400 rows and 62 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# C:\Users\yanhui\AppData\Local\Temp\ipykernel_12520\384558770.py:61: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   delta0['delta0']*(S1_i-S0) + delta1[S1_i]*(S2_j-S1_i)
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9400 nonzeros
# Model fingerprint: 0x75fb9942
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 4e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 7e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 9400 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.927961e+03   0.000000e+00      0s
#       35    1.7297238e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.729723835e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9459 nonzeros
# Model fingerprint: 0xa9160b4a
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 8e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 399 rows, 62 columns, 9445 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.639408e+03   0.000000e+00      0s
#       33    6.9147949e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  6.914794949e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11260 nonzeros
# Model fingerprint: 0x1d1db2e0
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 8e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 360 rows, 60 columns, 10688 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.547220e+03   0.000000e+00      0s
#       27    8.1515377e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  8.151537659e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11600 nonzeros
# Model fingerprint: 0x67a2ee59
# Coefficient statistics:
#   Matrix range     [7e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 8e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 360 rows, 60 columns, 10954 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.685855e+03   0.000000e+00      0s
#       32    7.9826794e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  7.982679404e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10800 nonzeros
# Model fingerprint: 0x59b1876f
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 8e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10800 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.557418e+03   0.000000e+00      0s
#       34    1.2503804e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.250380430e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10455 nonzeros
# Model fingerprint: 0x78bc6219
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 8e+02]
# Presolve removed 23 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 377 rows, 61 columns, 10082 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.909868e+03   0.000000e+00      0s
#       27    7.9335252e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  7.933525170e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10780 nonzeros
# Model fingerprint: 0x0b2a3615
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+00, 7e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 10780 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.454523e+03   0.000000e+00      0s
#       36    1.2294374e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.229437392e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 12380 nonzeros
# Model fingerprint: 0xd610139c
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 9e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 12380 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.529638e+03   0.000000e+00      0s
#       27    8.0437996e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 27 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  8.043799633e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11899 nonzeros
# Model fingerprint: 0x0a878878
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+00, 9e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 399 rows, 62 columns, 11859 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.190921e+03   0.000000e+00      0s
#       32    1.0068832e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.006883152e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11940 nonzeros
# Model fingerprint: 0xc4e00378
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 7e+02]
# Presolve removed 40 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 360 rows, 59 columns, 10536 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.145559e+03   0.000000e+00      0s
#       35    9.9823994e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 35 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.982399382e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 12740 nonzeros
# Model fingerprint: 0x3a0239d3
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [7e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 12740 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.865707e+03   0.000000e+00      0s
#       32    1.0303952e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  1.030395225e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 11500 nonzeros
# Model fingerprint: 0x655d2817
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [8e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 7e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 11500 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.124424e+03   0.000000e+00      0s
#       30    1.1467758e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 30 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.146775767e+02
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9979 nonzeros
# Model fingerprint: 0x50d44357
# Coefficient statistics:
#   Matrix range     [5e-01, 5e+02]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 5e+02]
# Presolve time: 0.01s
# Presolved: 400 rows, 62 columns, 9979 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.219046e+03   0.000000e+00      0s
#       41    8.9406457e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 41 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  8.940645653e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 10820 nonzeros
# Model fingerprint: 0x76730f5e
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [0e+00, 0e+00]
# ...
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 8919 nonzeros
# Model fingerprint: 0xc0cb26b8
# Coefficient statistics:
#   Matrix range     [2e-01, 2e+02]
#   Objective range  [1e-02, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8268 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.7142592e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.714259163e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9539 nonzeros
# Model fingerprint: 0xd20e8163
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [1e-02, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8872 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       36    3.7291625e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.729162518e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 8979 nonzeros
# Model fingerprint: 0xd46c54e3
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [1e-02, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8321 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       36    3.7287153e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 36 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.728715311e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9319 nonzeros
# Model fingerprint: 0xbcffc932
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8656 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.6491438e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.649143783e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 8959 nonzeros
# Model fingerprint: 0x74238ace
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8302 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.6964261e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.696426051e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9300 nonzeros
# Model fingerprint: 0xff3f2b55
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 60 columns, 8054 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       32    3.5405004e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 32 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.540500408e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9099 nonzeros
# Model fingerprint: 0x0e19ecf1
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 380 rows, 61 columns, 8438 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.6563969e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.656396910e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9099 nonzeros
# Model fingerprint: 0xc3c0bc36
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8443 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       42    3.6388232e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.638823230e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9239 nonzeros
# Model fingerprint: 0xfd917556
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8571 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       42    3.5414222e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 42 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.541422202e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9400 nonzeros
# Model fingerprint: 0xfc4a0a5d
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 60 columns, 8136 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.4120124e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.412012384e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9159 nonzeros
# Model fingerprint: 0x24644b84
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8496 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       41    3.5840033e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 41 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.584003343e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9219 nonzeros
# Model fingerprint: 0xa7fb13da
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8557 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.5796100e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.579609970e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9080 nonzeros
# Model fingerprint: 0xd28e8626
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 60 columns, 7842 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.4256172e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.425617233e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 8800 nonzeros
# Model fingerprint: 0x70db9415
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-01, 2e+02]
# Presolve removed 80 rows and 4 columns
# Presolve time: 0.01s
# Presolved: 320 rows, 58 columns, 7008 nonzeros
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.099095e+03   0.000000e+00      0s
#       31    3.0457348e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 31 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  3.045734790e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9419 nonzeros
# Model fingerprint: 0xfa0891a5
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+00, 2e+02]
# Presolve removed 20 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 380 rows, 61 columns, 8746 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.334375e+03   0.000000e+00      0s
#       38    3.5634602e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 38 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.563460239e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9120 nonzeros
# Model fingerprint: 0x8ecb3f9d
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+02]
#   Objective range  [5e-03, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-01, 2e+02]
# Presolve removed 40 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 360 rows, 60 columns, 7826 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.177895e+03   0.000000e+00      0s
#       33    3.4946342e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.494634163e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9140 nonzeros
# Model fingerprint: 0xb6dc7d84
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 60 columns, 7894 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.3802477e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.380247678e+01
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22000.2))
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 400 rows, 62 columns and 9520 nonzeros
# Model fingerprint: 0x027e6e9a
# Coefficient statistics:
#   Matrix range     [5e-01, 2e+02]
#   Objective range  [5e-03, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 48 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 352 rows, 60 columns, 8243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.235526e+03   0.000000e+00      0s
#       34    3.3633065e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 34 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  3.363306502e+01

# %%
gap_T1[(gap_T1<=60) & (gap_T1>=-60)].mean().sort_index().plot()
# Out:
# <Axes: >

# %%
pd.DataFrame(gap_T1).to_csv('resultGap1Month.csv')

# %%
gap_T1.median().sort_index().plot()
# Out:
# <Axes: >
